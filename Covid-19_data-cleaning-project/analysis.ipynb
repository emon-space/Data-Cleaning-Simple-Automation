# %%
# Import all the important libraies
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# Load the data and overview it
df = pd.read_csv("country_wise_latest.csv")
df.head()
# Out:
#   Country/Region  Confirmed  Deaths  Recovered  Active  New cases  New deaths  \
# 0    Afghanistan      36263    1269      25198    9796        106          10
# 1        Albania       4880     144       2745    1991        117           6
# 2        Algeria      27973    1163      18837    7973        616           8
# 3        Andorra        907      52        803      52         10           0
# 4         Angola        950      41        242     667         18           1
#
#    New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# 0             18                3.50                  69.49
# 1             63                2.95                  56.25
# 2            749                4.16                  67.34
# 3              0                5.73                  88.53
# 4              0                4.32                  25.47
#
#    Deaths / 100 Recovered  Confirmed last week  1 week change  \
# 0                    5.04                35526            737
# 1                    5.25                 4171            709
# 2                    6.17                23691           4282
# 3                    6.48                  884             23
# 4                   16.94                  749            201
#
#    1 week % increase             WHO Region
# 0               2.07  Eastern Mediterranean
# 1              17.00                 Europe
# 2              18.07                 Africa
# 3               2.60                 Europe
# 4              26.84                 Africa

# %% [markdown]
# The raw dataset contains country-level data with multiple numerical indicators.
# Before analysis, column names, missing values, and data consistency must be checked.

# %%
# Standardize column names
df.columns = (
    df.columns
    .str.lower()
    .str.strip()
    .str.replace(" ", "_")
)
df.head()
# Out:
#   country/region  confirmed  deaths  recovered  active  new_cases  new_deaths  \
# 0    Afghanistan      36263    1269      25198    9796        106          10
# 1        Albania       4880     144       2745    1991        117           6
# 2        Algeria      27973    1163      18837    7973        616           8
# 3        Andorra        907      52        803      52         10           0
# 4         Angola        950      41        242     667         18           1
#
#    new_recovered  deaths_/_100_cases  recovered_/_100_cases  \
# 0             18                3.50                  69.49
# 1             63                2.95                  56.25
# 2            749                4.16                  67.34
# 3              0                5.73                  88.53
# 4              0                4.32                  25.47
#
#    deaths_/_100_recovered  confirmed_last_week  1_week_change  \
# 0                    5.04                35526            737
# 1                    5.25                 4171            709
# 2                    6.17                23691           4282
# 3                    6.48                  884             23
# 4                   16.94                  749            201
#
#    1_week_%_increase             who_region
# 0               2.07  Eastern Mediterranean
# 1              17.00                 Europe
# 2              18.07                 Africa
# 3               2.60                 Europe
# 4              26.84                 Africa

# %%
# Check missing values
df.isnull().sum()

# Fill or handle missing values
numeric_cols = df.select_dtypes(include=np.number).columns
df[numeric_cols] = df[numeric_cols].fillna(0)

# %% [markdown]
# Missing numerical values are filled with 0 to ensure consistency
# for aggregation and analysis.

# %%
# Remove duplicates
df = df.drop_duplicates()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 187 entries, 0 to 186
# Data columns (total 15 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   country/region          187 non-null    object
#  1   confirmed               187 non-null    int64
#  2   deaths                  187 non-null    int64
#  3   recovered               187 non-null    int64
#  4   active                  187 non-null    int64
#  5   new_cases               187 non-null    int64
#  6   new_deaths              187 non-null    int64
#  7   new_recovered           187 non-null    int64
#  8   deaths_/_100_cases      187 non-null    float64
#  9   recovered_/_100_cases   187 non-null    float64
#  10  deaths_/_100_recovered  187 non-null    float64
#  11  confirmed_last_week     187 non-null    int64
#  12  1_week_change           187 non-null    int64
#  13  1_week_%_increase       187 non-null    float64
#  14  who_region              187 non-null    object
# dtypes: float64(4), int64(9), object(2)
# memory usage: 22.0+ KB

# %%
# structured analytical view
clean_df = df[
    [
        "country/region",
        "who_region",
        "confirmed",
        "deaths",
        "recovered",
        "active",
        "new_cases",
        "new_deaths",
        "new_recovered"
    ]
]
clean_df.head()
# Out:
#   country/region             who_region  confirmed  deaths  recovered  active  \
# 0    Afghanistan  Eastern Mediterranean      36263    1269      25198    9796
# 1        Albania                 Europe       4880     144       2745    1991
# 2        Algeria                 Africa      27973    1163      18837    7973
# 3        Andorra                 Europe        907      52        803      52
# 4         Angola                 Africa        950      41        242     667
#
#    new_cases  new_deaths  new_recovered
# 0        106          10             18
# 1        117           6             63
# 2        616           8            749
# 3         10           0              0
# 4         18           1              0

# %%
# Summary statistics
clean_df.describe()
# Out:
#           confirmed         deaths     recovered        active     new_cases  \
# count  1.870000e+02     187.000000  1.870000e+02  1.870000e+02    187.000000
# mean   8.813094e+04    3497.518717  5.063148e+04  3.400194e+04   1222.957219
# std    3.833187e+05   14100.002482  1.901882e+05  2.133262e+05   5710.374790
# min    1.000000e+01       0.000000  0.000000e+00  0.000000e+00      0.000000
# 25%    1.114000e+03      18.500000  6.265000e+02  1.415000e+02      4.000000
# 50%    5.059000e+03     108.000000  2.815000e+03  1.600000e+03     49.000000
# 75%    4.046050e+04     734.000000  2.260600e+04  9.149000e+03    419.500000
# max    4.290259e+06  148011.000000  1.846641e+06  2.816444e+06  56336.000000
#
#         new_deaths  new_recovered
# count   187.000000     187.000000
# mean     28.957219     933.812834
# std     120.037173    4197.719635
# min       0.000000       0.000000
# 25%       0.000000       0.000000
# 50%       1.000000      22.000000
# 75%       6.000000     221.000000
# max    1076.000000   33728.000000

# %%
# Simple ranking
top_countries = clean_df.sort_values(
    by="confirmed",
    ascending=False
).head(10)

top_countries
#Save clean output
clean_df.to_csv("clean_data.csv", index=False)
# Out:
#         country/region             who_region  confirmed  deaths  recovered  \
# 0          Afghanistan  Eastern Mediterranean      36263    1269      25198
# 1              Albania                 Europe       4880     144       2745
# 2              Algeria                 Africa      27973    1163      18837
# 3              Andorra                 Europe        907      52        803
# 4               Angola                 Africa        950      41        242
# 5  Antigua and Barbuda               Americas         86       3         65
# 6            Argentina               Americas     167416    3059      72575
# 7              Armenia                 Europe      37390     711      26665
# 8            Australia        Western Pacific      15303     167       9311
# 9              Austria                 Europe      20558     713      18246
#
#    active  new_cases  new_deaths  new_recovered
# 0    9796        106          10             18
# 1    1991        117           6             63
# 2    7973        616           8            749
# 3      52         10           0              0
# 4     667         18           1              0
# 5      18          4           0              5
# 6   91782       4890         120           2057
# 7   10014         73           6            187
# 8    5825        368           6            137
# 9    1599         86           1             37
